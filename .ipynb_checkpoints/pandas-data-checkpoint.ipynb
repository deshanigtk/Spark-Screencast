# %%
import pandas as pd
from sklearn.utils import shuffle

# %%
df = pd.read_csv("death-causes-us.csv")
df
# Out:
#        Year                                     113_Cause_Name  \
# 0      2012  Nephritis, nephrotic syndrome and nephrosis (N...
# 1      2016  Nephritis, nephrotic syndrome and nephrosis (N...
# 2      2013  Nephritis, nephrotic syndrome and nephrosis (N...
# 3      2000  Intentional self-harm (suicide) (*U03,X60-X84,...
# 4      2014  Nephritis, nephrotic syndrome and nephrosis (N...
# 5      2009  Intentional self-harm (suicide) (*U03,X60-X84,...
# 6      2011  Nephritis, nephrotic syndrome and nephrosis (N...
# 7      2015  Nephritis, nephrotic syndrome and nephrosis (N...
# 8      2014  Nephritis, nephrotic syndrome and nephrosis (N...
# 9      2013  Nephritis, nephrotic syndrome and nephrosis (N...
# 10     2015  Intentional self-harm (suicide) (*U03,X60-X84,...
# 11     2001  Nephritis, nephrotic syndrome and nephrosis (N...
# 12     1999  Intentional self-harm (suicide) (*U03,X60-X84,...
# 13     1999  Nephritis, nephrotic syndrome and nephrosis (N...
# ...

# %%
df = shuffle(df)
df.reset_index(level=0, inplace=True)

# %%
df = df.drop(df.iloc[10000:])

# %%
df
# Out:
#       index  Year                                     113_Cause_Name  \
# 0      7190  2013       Chronic lower respiratory diseases (J40-J47)
# 1      6999  2016       Chronic lower respiratory diseases (J40-J47)
# 2      9643  2015                                         All Causes
# 3      2608  2006  Intentional self-harm (suicide) (*U03,X60-X84,...
# 4      6895  2010       Chronic lower respiratory diseases (J40-J47)
# 5      2391  2014                        Diabetes mellitus (E10-E14)
# 6      5409  2011  Accidents (unintentional injuries) (V01-X59,Y8...
# 7      5643  2006       Chronic lower respiratory diseases (J40-J47)
# 8      7800  2011        Diseases of heart (I00-I09,I11,I13,I20-I51)
# 9      9297  2003        Diseases of heart (I00-I09,I11,I13,I20-I51)
# 10    10146  2013                                         All Causes
# 11     4339  2005                          Alzheimer's disease (G30)
# 12     2459  2003  Nephritis, nephrotic syndrome and nephrosis (N...
# ...

# %%
df.loc[df["Year"]==2010]
# Out:
#       index  Year                                     113_Cause_Name  \
# 4      6895  2010       Chronic lower respiratory diseases (J40-J47)
# 39     8407  2010                      Malignant neoplasms (C00-C97)
# 62     5798  2010  Accidents (unintentional injuries) (V01-X59,Y8...
# 63     8396  2010                      Malignant neoplasms (C00-C97)
# 81     9599  2010                                         All Causes
# 97     4321  2010  Accidents (unintentional injuries) (V01-X59,Y8...
# 114    6253  2010       Chronic lower respiratory diseases (J40-J47)
# 122    7522  2010        Diseases of heart (I00-I09,I11,I13,I20-I51)
# 133   10021  2010                                         All Causes
# 170    1933  2010  Intentional self-harm (suicide) (*U03,X60-X84,...
# 191    3743  2010  Accidents (unintentional injuries) (V01-X59,Y8...
# 204    5735  2010  Accidents (unintentional injuries) (V01-X59,Y8...
# 205    2710  2010                  Influenza and pneumonia (J09-J18)
# ...

# %%
df.to_csv("death-2.csv", index=False)
