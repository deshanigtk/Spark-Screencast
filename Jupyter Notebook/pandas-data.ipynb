# %%
import pandas as pd
from sklearn.utils import shuffle

# %%
df = pd.read_csv("death-causes-us.csv")
df
# Out:
#        Year                                     113_Cause_Name  \
# 0      2012  Nephritis, nephrotic syndrome and nephrosis (N...
# 1      2016  Nephritis, nephrotic syndrome and nephrosis (N...
# 2      2013  Nephritis, nephrotic syndrome and nephrosis (N...
# 3      2000  Intentional self-harm (suicide) (*U03,X60-X84,...
# 4      2014  Nephritis, nephrotic syndrome and nephrosis (N...
# 5      2009  Intentional self-harm (suicide) (*U03,X60-X84,...
# 6      2011  Nephritis, nephrotic syndrome and nephrosis (N...
# 7      2015  Nephritis, nephrotic syndrome and nephrosis (N...
# 8      2014  Nephritis, nephrotic syndrome and nephrosis (N...
# 9      2013  Nephritis, nephrotic syndrome and nephrosis (N...
# 10     2015  Intentional self-harm (suicide) (*U03,X60-X84,...
# 11     2001  Nephritis, nephrotic syndrome and nephrosis (N...
# 12     1999  Intentional self-harm (suicide) (*U03,X60-X84,...
# 13     1999  Nephritis, nephrotic syndrome and nephrosis (N...
# ...

# %%
df = shuffle(df)
df.reset_index(level=0, inplace=True)

# %%
df = df.iloc[0:10000]

# %%
df
# Out:
#       index  Year                                     113_Cause_Name  \
# 0      2026  2008                  Influenza and pneumonia (J09-J18)
# 1      8236  2005                      Malignant neoplasms (C00-C97)
# 2      1014  2007  Intentional self-harm (suicide) (*U03,X60-X84,...
# 3      5259  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 4      7673  2013        Diseases of heart (I00-I09,I11,I13,I20-I51)
# 5      3952  2009                        Diabetes mellitus (E10-E14)
# 6      1377  2011  Nephritis, nephrotic syndrome and nephrosis (N...
# 7      9264  2000        Diseases of heart (I00-I09,I11,I13,I20-I51)
# 8      8641  2003                      Malignant neoplasms (C00-C97)
# 9       985  2013  Intentional self-harm (suicide) (*U03,X60-X84,...
# 10     9095  2009        Diseases of heart (I00-I09,I11,I13,I20-I51)
# 11     5812  2015                          Alzheimer's disease (G30)
# 12     8670  1999                      Malignant neoplasms (C00-C97)
# ...

# %%
df.loc[df["Year"]==2010]
# Out:
#       index  Year                                     113_Cause_Name  \
# 37     3439  2010                        Diabetes mellitus (E10-E14)
# 46     1066  2010  Intentional self-harm (suicide) (*U03,X60-X84,...
# 57     8379  2010        Diseases of heart (I00-I09,I11,I13,I20-I51)
# 83     7689  2010        Diseases of heart (I00-I09,I11,I13,I20-I51)
# 93     5227  2010  Accidents (unintentional injuries) (V01-X59,Y8...
# 115    1895  2010                  Influenza and pneumonia (J09-J18)
# 117     904  2010  Intentional self-harm (suicide) (*U03,X60-X84,...
# 127    1758  2010  Intentional self-harm (suicide) (*U03,X60-X84,...
# 143    4443  2010                          Alzheimer's disease (G30)
# 155    3022  2010                        Diabetes mellitus (E10-E14)
# 167    1307  2010  Intentional self-harm (suicide) (*U03,X60-X84,...
# 173    3870  2010                          Alzheimer's disease (G30)
# 203    1806  2010                        Diabetes mellitus (E10-E14)
# ...

# %%
df.to_csv("death-2.csv", index=False)
